# %%
from PIL import Image
import os

os.getcwd()
# Out:
# 'C:\\Users\\User\\IMAGE PROCESSING'

# %%
image1 = Image.open("fface.jpg")

image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x1F5E37CFE80>

# %%
image1.show()

# %%
image1.save("pic1.png")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1img.png',
#  '2img.png',
#  '4.png',
#  'a.png',
#  'aaa.jpg',
#  'b.png',
#  'canvas.ipynb',
#  'cat.png',
#  'cat_damaged.png',
#  'cat_inpainted.png',
#  'cat_mask.png',
#  'contour shapes.ipynb',
#  'convert matrix into image.ipynb',
#  'crop.png',
#  'dice.jpg',
#  'differnce between 2 pictures.ipynb',
#  'drawing contour lines for an image.ipynb',
#  'example 1.ipynb',
#  'example 2.ipynb',
#  'example 3.ipynb',
#  'face.jpg',
#  'face1.jpg',
#  'fface.jpg',
#  'flower.png',
#  'hor.jpg',
#  'horse.jpg',
#  'horsee.png',
#  'image manipulation.ipynb',
#  'image restoration.ipynb',
#  'Image_from_array.png',
#  'intensity transformation.ipynb',
#  'lag.png',
#  'listing pictures.ipynb',
#  'montage.ipynb',
#  'montage.png',
#  'nature.jpg',
#  'noice.ipynb',
#  'noisy image.ipynb',
#  'pic1.png',
#  'pruits.jpg',
#  'rotation.ipynb',
#  'sampling updation.ipynb',
#  'segmentation.ipynb',
#  'template.png',
#  'text remove.ipynb',
#  'text.png',
#  'text_removed_image.jpg',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'watermark.ipynb',
#  'watermark.png']

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        print(fn, "&", fext)
# Out:
# aaa & .jpg
# dice & .jpg
# face & .jpg
# face1 & .jpg
# fface & .jpg
# hor & .jpg
# horse & .jpg
# nature & .jpg
# pruits & .jpg
# text_removed_image & .jpg

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        print(f)
# Out:
# aaa.jpg
# dice.jpg
# face.jpg
# face1.jpg
# fface.jpg
# hor.jpg
# horse.jpg
# nature.jpg
# pruits.jpg
# text_removed_image.jpg

# %%
os.mkdir('NewExtnsn')

# %%
for f in os.listdir("."):
    if f.endswith(".png"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.save("NewExtnsn/{}.pdf".format(fn))

# %%
#resizing

os.makedirs('resize//small')
os.makedirs('resize//tiny')

# %%
size_small = (600,600) # small images of 600 X 600 pixels
size_tiny = (200,200)  # tiny images of 200 X 200 pixels
for f in os.listdir("."):
    if f.endswith(".png"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.thumbnail(size_small)
        i.save("resize/small/{}_small{}".format(fn, fext))
        i.thumbnail(size_tiny)
        i.save("resize/tiny/{}_tiny{}".format(fn, fext))

# %%
#rotating

#rotating the image to 55 Degree angle
image3 = Image.open("cat.png")
image3.rotate(55).save("image3.jpg")
Image3 = Image.open("image3.jpg")
Image3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x230 at 0x1F5E39CCC70>

# %%
# Creating new Directory using OS library
os.mkdir('rotate')
for f in os.listdir("."):
    if f.endswith(".png"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        im = i.rotate(90)
        im.save("rotate/{}_rot.{}".format(fn, fext))
