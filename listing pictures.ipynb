# %%
#listing only png images
import os
from os import listdir
 
# get the path/directory
folder_dir = "C:/Users/User/Downloads"
for images in os.listdir(folder_dir):
 
    # check if the image ends with png
    if (images.endswith(".png")):
        print(images)
# Out:
# 1img.png
# 2img.png
# box.png
# cat.png
# cat_damaged.png
# cat_mask.png
# crop (1).png
# crop.png
# img.png
# lag.png
# square.png
# sss.png
# template.png
# text.png
# watermark.png
# wine-bottle.png

# %%
#lisiting all the mages
import os
from os import listdir
 
# get the path/directory
folder_dir = "C:/Users/User/Downloads"
for images in os.listdir(folder_dir):
    print(images)
# Out:
# !qhlogs.doc
# 1img.png
# 2.jfif
# 2img.png
# aa.jfif
# aaa.jpg
# AG-s-News-Topic-Classification-Using-LSTM-Neural-Networks-master.zip
# android-studio-2021.3.1.17-windows.exe
# bb.jfif
# bhoomi.jpg
# box.png
# bunny.jfif
# CART.xlsx
# cat.png
# cat_damaged.png
# cat_mask.png
# Clustering_ex.xlsx
# crop (1).png
# crop.png
# damaged.jpg
# desktop.ini
# Dev-Cpp 5.11 TDM-GCC 4.9.2 Setup (1).exe
# Dev-Cpp 5.11 TDM-GCC 4.9.2 Setup.exe
# Dev_C___v6.3 (1).zip
# Dev_C___v6.3 (2).zip
# Dev_C___v6.3.zip
# differnce between 2 pictures.ipynb
# differnce between 2 pictures.py
# download (1).jfif
# download (2).jfif
# download (3).jfif
# download (4).jfif
# download (5).jfif
# download.jfif
# drawing contour lines for an image.ipynb
# drawing contour lines for an image.py
# example 1.ipynb
# example 1.py
# example 2.ipynb
# example 2.py
# example 3.ipynb
# example 3.py
# Googlelens (1).txt
# Googlelens.txt
# googlelensdata1.csv
# googlelensdataset.txt
# he.jpg
# image manipulation.ipynb
# image manipulation.py
# images (1).jfif
# images (2).jfif
# images (3).jfif
# images.jfif
# imageswine.jpg
# img.png
# intensity transformation.ipynb
# intensity transformation.py
# ipmsg499r11_installer.exe
# lablist2022.docx
# lag.png
# letter.jpg
# montage (1).ipynb
# montage (1).py
# montage (2).py
# montage.ipynb
# montage.py
# moon.jfif
# nai.jfif
# nature.jpg
# noisy image (1).py
# noisy image.ipynb
# noisy image.py
# noisy.jfif
# npp.8.4.1.Installer.x64.exe
# nse_bhavcopy_2020 (1).parquet
# nse_bhavcopy_2020.parquet
# nse_bhavcopy_2020.zip
# oneway.xlsx
# Poovari (1).txt
# Poovari.txt
# regcar.xlsx
# Register_login.docx
# ring.mp3
# ring2.mp3
# sampledataset.txt
# sampling updation.ipynb
# sampling updation.py
# sampling.ipynb
# sampling.py
# sanskrit-text-segmentation.crfsuite
# Second_IA
# Second_IA.rar
# skipgram.ipynb
# sky.jfif
# Smart Parking System.docx
# square.png
# sss.png
# stbook.txt
# storyb.txt
# storybooks OCR (1).txt
# storybooks OCR (2).txt
# storybooks OCR.txt
# template.png
# text remove.ipynb
# text remove.py
# text.png
# Turbo.C.3.2 (1).zip
# Turbo.C.3.2.zip
# Untitled (1).ipynb
# Untitled.ipynb
# Untitled.py
# watermark.ipynb
# watermark.png
# watermark.py
# wine-bottle.png
# winebottle.jpg
# ~$blist2022.docx

# %%
import cv2 
import os 
import glob 
img_dir = "C:/Users/User/Downloads" # Enter Directory of all images  
data_path = os.path.join(img_dir,'*g') 
files = glob.glob(data_path) 
data = [] 
for f1 in files: 
    img = cv2.imread(f1) 
    data.append(img)

# %%
#displaying all the images from the folder
import cv2 
import os 
import glob 
import matplotlib.pyplot as plt 
# %matplotlib inline 
 
#Set the path where images are stored 
img_dir = "C:/Users/User/Downloads" # Enter Directory of all images  
data_path = os.path.join(img_dir,'*g') 
files = glob.glob(data_path) 
data = [] 
for f1 in files: 
    img = plt.imread(f1,0) 
    data.append(img) 
    plt.figure() 
    plt.title("original Image")
    plt.imshow(img) 
for f1 in files: 
    img = plt.imread(f1,0) 
    data.append(img) 
    resize=cv2.resize(img,(100,100))
    plt.figure() 
    plt.title("resized Image")
    plt.imshow(resize)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_12592/739476715.py:16: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
