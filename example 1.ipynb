# %%
import cv2
image=cv2.imread("download.jfif",0)

cv2.imshow('to display images',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite("F:/jayashrinidhi/im1.png",image)
# Out:
# True

# %%
#loading from external drive
image=cv2.imread("C:/Users/User/Downloads/images.jfif")
cv2.imshow('to display images',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#height and width
from PIL import Image

x="download (4).jfif"
img=Image.open(x)
width=img.width
height=img.height

print("The width of the image is",width)
print("The height of the image is",height)
# Out:
# The width of the image is 278
# The height of the image is 181

# %%
#no of channelsin color omage

import numpy
img=cv2.imread("download (5).jfif")
print("No of channels is:"+str(img.ndim))
print("No of channels is:",img.shape)
cv2.imshow("channel",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# No of channels is:3
# No of channels is: (183, 276, 3)

# %%
#no of channels in greyscale omage

import numpy
img=cv2.imread("download (5).jfif",0)
print("No of channels is:"+str(img.ndim))
print("No of channels is:",img.shape)
ret,bw_img=cv2.threshold(img,127,225,cv2.THRESH_BINARY)
# Out:
# No of channels is:2
# No of channels is: (183, 276)

# %%
#resize image
from PIL import Image
filepath="download (5).jfif"
im=Image.open(filepath)
new_im=im.resize((400,400))
new_im
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x1A49DF100A0>

# %%
#matrix respresenation

import matplotlib.image as image
img=image.imread("images.jfif")
print("The shape of the image is",img.shape)
print("The array of the image is")
print(img)
# Out:
# The shape of the image is (194, 259, 3)
# The array of the image is
# [[[18 31 13]
#   [ 6 19  1]
#   [ 0 12  0]
#   ...
#   [49 73 41]
#   [43 67 35]
#   [37 58 27]]
#
#  [[29 40 23]
#   [17 30 12]
#   [ 7 22  1]
#   ...
#   [51 76 44]
#   [46 71 39]
#   [40 64 32]]
#
#  [[20 31 14]
#   [13 26  8]
#   [10 25  4]
#   ...
#   [51 81 45]
#   [49 76 41]
#   [43 70 35]]
#
#  ...
#
#  [[47 84 51]
#   [44 84 49]
#   [42 84 46]
#   ...
#   [47 90 34]
#   [47 90 34]
#   [46 89 33]]
#
#  [[49 84 51]
#   [47 85 48]
#   [43 84 44]
#   ...
#   [41 84 28]
#   [41 84 28]
#   [40 83 27]]
#
#  [[49 84 51]
#   [47 85 48]
#   [43 84 44]
#   ...
#   [41 84 28]
#   [41 84 28]
#   [40 83 27]]]

# %%
#binary image

import cv2
img=cv2.imread("images.jfif")
ret,bw_img=cv2.threshold(img,127,225,cv2.THRESH_BINARY)

#converting to its  binary form

bw=cv2.threshold(img,127,225,cv2.THRESH_BINARY)
cv2.imshow("BINARY",bw_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
img=cv2.imread("images.jfif")
B,G,R=cv2.split(img)
print(B)
print(G)
print(R)
# Out:
# [[13  0  0 ... 41 35 27]
#  [23 10  1 ... 44 39 32]
#  [14  6  4 ... 45 41 35]
#  ...
#  [51 49 46 ... 36 34 33]
#  [51 50 44 ... 30 28 27]
#  [51 48 44 ... 30 28 27]]
# [[31 20 12 ... 75 67 59]
#  [41 30 22 ... 78 71 64]
#  [31 26 25 ... 82 77 70]
#  ...
#  [84 84 84 ... 91 90 89]
#  [84 84 84 ... 85 84 83]
#  [84 85 84 ... 85 84 83]]
# [[18  5  0 ... 45 43 35]
#  [28 17  7 ... 47 46 39]
#  [20 13 10 ... 48 47 43]
#  ...
#  [47 44 42 ... 46 47 46]
#  [49 47 43 ... 40 41 40]
#  [49 47 43 ... 40 41 40]]

# %%
img=cv2.imread("images.jfif")
cv2.imshow("original",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("BLUE",B)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("GREEN",G)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("RED",R)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#ASPECT RATIO
img=cv2.imread("images.jfif")
new_im=im.resize((400,200))
ar=1*(img.shape[1]/img.shape[0])
print("Aspect ratio")
print(ar)
# Out:
# Aspect ratio
# 1.3350515463917525

# %%
#mirror image
from PIL import Image, ImageOps
im = Image.open("download.jfif")
hori_filppedImage=im.transpose(Image.FLIP_LEFT_RIGHT)
hori_filppedImage.show()

vert_filppedImage=im.transpose(Image.FLIP_TOP_BOTTOM)
vert_filppedImage.show()

# %%
import cv2
img1=cv2.imread("nai.jfif")
img2=cv2.imread("bunny.jfif")
sum=img1+img2
sub=img1-img2
mul=img1*img2
div=img1/img2
cv2.imshow("sub",sub)
cv2.imshow("sum",sum)
cv2.imshow("mul",mul)
cv2.imshow("div",div)
cv2.waitKey(0)
cv2.destroyAllWindows()
